# %% [markdown]
# # Base script for Ocean Parcels to use for sensitivity analysis.

# %% [markdown]
# Author: Johanna Wren
#
# email: johanna.wren@noaa.gov
#
# Date: September 21, 2021

# %% [markdown]
# Basic script for use during sensitivity analysis for LAPS modeling. This script advects particles in pre-defined locations at a pre-defined depth using HYCOM currents stored on file. The trajectories are saved as a NetCDF file. This script contains a particle age (PLD) but no land avoidance and uses 2D passive dispersal with diffusivity.
#
# The script also calculates cumulative distance traveled.

# %% [markdown]
# ## Load libraries
# Loading all the libraries we need for basic 2D fourth order Runge-Kutta dispersal with diffusion.

# %%
# Load libraries etc.
from parcels import FieldSet, ParticleSet, JITParticle, ErrorCode, plotTrajectoriesFile, Variable, ParcelsRandom, Field, DiffusionUniformKh #, AdvectionRK4#
import numpy as np
import pandas as pd
import xarray as xr
from datetime import timedelta, datetime
import math
import haversine as hs

# %% [markdown]
# Define custom AdvectionRK4 kernel so we can get the previous lon and lat for distance calculations. Nothing has changed from the original other than adding the prev_lat and prev_lon bits

# %% [markdown]
# ## Define custom kenels
# This is where we define other useful custom kenels.

# %% [markdown]
# First we have to slightly change the `AdvectionRK4` function. This is a build in function in OceanParcels but we need to save the previous particle location so that we can calculate distance traveled for a particle. We do that here by adding `particle.prev_lon` and `particle.prev_lat` to the source code. Make sure you don't load the `AdvectionRK4` up top in the script if you run this custom version.

# %%
def AdvectionRK4(particle, fieldset, time):
    """Advection of particles using fourth-order Runge-Kutta integration.

    Function needs to be converted to Kernel object before execution"""
    particle.prev_lon = particle.lon
    particle.prev_lat = particle.lat
    
    (u1, v1) = fieldset.UV[particle]
    lon1, lat1 = (particle.lon + u1*.5*particle.dt, particle.lat + v1*.5*particle.dt)
    (u2, v2) = fieldset.UV[time + .5 * particle.dt, particle.depth, lat1, lon1, particle]
    lon2, lat2 = (particle.lon + u2*.5*particle.dt, particle.lat + v2*.5*particle.dt)
    (u3, v3) = fieldset.UV[time + .5 * particle.dt, particle.depth, lat2, lon2, particle]
    lon3, lat3 = (particle.lon + u3*particle.dt, particle.lat + v3*particle.dt)
    (u4, v4) = fieldset.UV[time + particle.dt, particle.depth, lat3, lon3, particle]
    particle.lon += (u1 + 2*u2 + 2*u3 + u4) / 6. * particle.dt
    particle.lat += (v1 + 2*v2 + 2*v3 + v4) / 6. * particle.dt

# %% [markdown]
# ### DELETE PARTICLES
# `DeleteParticles` allows for particles to be deleted when they exit the dispersal domain. This is applied to the borders of the domain but NOT to land.
#
# *NOTE: When currents are loaded into the fieldset the missing values over land get converted to zeros so particles that hit land just stop there and bunch up. This shouldn't be a problem for this application, but if it is, we can add land avoidance kernels.*

# %%
def DeleteParticle(particle, fieldset, time):
    particle.delete()

# %% [markdown]
# ### AGEING
# The `Ageing` kernel removes particles after a specific time period (PLD) by calling the `DeleteParticles` kernel. This allows you to run simulation for long periods of time while removing particles after a set number of days. We read in the PLD as a constant in the fieldset and this kernel grabs the PLD value from there.

# %%
def Ageing(particle, fieldset, time):
    particle.age += particle.dt
    if particle.age >= fieldset.pld:
        particle.delete()

# %% [markdown]
# ### DISTANCE TRAVELED
# Here we calculate distance traveled. Since Parcels won't allow anything but basic math functions in a kernel we have to 'manually' calculate the distance and define $\pi$. I used the Haversine formula for this calculation, and the output is in **METERS**.
#
# If you don't want to calculate distance here but do it all at the end, simply comment out the Distance kernel from below where you add the kernels together right before executing the run.

# %%
def Distance(particle, fieldset, time):
    """
    Calculate the great circle distance in kilometers between two points 
    on the earth (specified in decimal degrees)
    """
    pi=3.14159265359
    # convert decimal degrees to radians 
    lon11 = particle.prev_lon*(pi/180)
    lat11 = particle.prev_lat*(pi/180)
    lon22 = particle.lon*(pi/180)
    lat22 = particle.lat*(pi/180)

    # haversine formula 
    dlon = lon22 - lon11 
    dlat = lat22 - lat11 
    a = sin(dlat/2)**2 + cos(lat11) * cos(lat22) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6378137 #6371 # Radius of earth in meters. Use 3956 for miles. Determines return value units.
    particle.distance += c * r

# %% [markdown]
# ## Create a fieldset
# We are creating a fieldset from HYCOM current files downloaded and stored on a drive. The fieldset is what OceanParcels uses to store all the information it needs for the flowfield that it moves particles through.
#
# The HYCOM data was downloaded using the `HYCOM_download_sensitivity.jnl` script and grabs u and v currents for a region 120E-120W and 0-50N for the top 50 meters (15 layers of the model). The files are saved as HYCOM_LAPS_Sensitivity_????.nc where the number indexing is days since the start of the dataseries on Jan 1, 1994. The HYCOM data can be found on the [APDRC website](http://apdrc.soest.hawaii.edu/erddap/griddap/hawaii_soest_6a0a_5127_d118).
#
# Because these files were saved using Ferret the lon and lat variable names are a bit different but it shouldn't change anything practically. You can always check the variable names by reading them R using the `ncdf4` package or through `ncdump -h HYCOM_LAPS_Sensitivity_7117.nc` command in your terminal (on a unix/linux machine).
#
# When you generate the fieldset, don't forget to <span style="color:red">**set your dept variable here to whichever depth strata you want to use.**</span>

# %%
filename = "2013Data/HYCOM_LAPS_Sensitivity_*.nc"
variables = {'U': 'WATER_U',
             'V': 'WATER_V'}
dimensions = {'lat': 'LATITUDE1501_2251',
              'lon': 'LONGITUDE3751_5251',
              'depth': 'LEV1_15',
              'time': 'TIME'}
fieldset = FieldSet.from_netcdf(filename, variables, dimensions)

# %% [markdown]
# Run some diagnostics on the `fieldset` to make sure it is read in properly. If your dataset is straddeling the 180 longitude, Parcels might plot the map in +-180 so the fieldset isn't continuous geographically, but that is just the plotting function, it still works fine and advects across the 180 meridian.

# %%
# Plot the U field
fieldset.U.show()

# %% [markdown]
# ## Add diffusivity
# In order for diffusivity to be incorporated we need to add zonal and meridional Kh fields. This code uses spatially homogenous diffusivity, but if you want spatially varying diffusivity use the `AdvectionDiffusionEM` or `AdvectionDiffusionM1` kernel instead.
#
# Skip the next cell if you want to run without diffusivity.

# %%
kh = 10   # This is the eddy diffusivity in m2/s

# Add even diffusivity to the fieldset
fieldset.add_constant_field('Kh_zonal', kh, mesh='spherical')
fieldset.add_constant_field('Kh_meridional', kh, mesh='spherical')

# %% [markdown]
# ## Add PLD
# Here we add the PLD as a constant to te fieldset. If you want to change up the PLD all you have to do is change the number here.

# %%
# Add PLD to fieldset
pld = 180   # in days
fieldset.add_constant('pld', (pld*86400))

# %% [markdown]
# ## Define your particle type
# We are using a JIT particle but we are adding the age variable along with a release site variable. These variables will print to the output file, but it's easy to change to not show in the ouput file.
#
# The release site is just a number for the island the particle was released from and makes it much easier when we construct connectivity matrices in post processing. The island values are listed in a separate column in your LAPS_release_sites.csv file.
#
# Since we are calculating distance traveled we need to add a few more vaiables to our particle. We need the distance calculation from the `Distance` kernel above, as well as the previous lon and lat (that we added in the `AdvectionRK4` above). We are not writing the previous lon and lat in the output file so but we do want the distance written to the file.

# %%
class AgeingParticle(JITParticle):
    age = Variable('age', dtype=np.float32, initial=0.)
    releaseSite = Variable('releaseSite', dtype=np.int32)
    distance = Variable('distance', dtype=np.int32, initial=0.)
    prev_lat = Variable('prev_lat', initial=0., to_write=False)  
    prev_lon = Variable('prev_lon', initial=0., to_write=False)

# %% [markdown]
# ## Set particle release locations
# Next, we instantiate a `ParticeSet` composed of `JITParticle`.
#
# `ParticleSet` holds release locations, the number of particles released, the release depth, and how often a particel should be released (daily, every 6h, etc.)
#
# Particles are released from locations specified in a file. We use this if we want to release at for example all reef locations in the islands, or any other list of locations. If we are releaseing multiple particles for each site we need to repeat them with the dates and depths and that is what we are doing with the `np.repeat` part.
#
# You can add or omit `pdepth`, `time` and `repeatdt` for a one time release at the default `fieldset` depth (in a multi depth file default is top layer) and time.

# %%
# Set input file
infile = pd.read_csv('LAPS_release_sites_noHI_3third.csv')

# Set number of particles you want to release
npart = 750

# Set the release depth
depth = 5

# Make vectors that repeat the release site and dept npart number of times
habilon = np.repeat(infile.Lon, npart)
habilat = np.repeat(infile.Lat, npart)
habisite = np.repeat(infile.Site, npart)
habidepth = np.repeat(depth, len(habilon))

# Time interval between particle release (in seconds)
release_int = 86400

# Start date for release (if you want it different from the first day of the currents in the fielset)
start_date = datetime(2013, 1, 1)

# Define the pset
pset = ParticleSet.from_list(fieldset=fieldset, 
                             pclass=AgeingParticle, 
                             lon=habilon,
                             lat=habilat,
                             depth=habidepth,
                             releaseSite=habisite,
                             repeatdt=release_int)

# %% [markdown]
# ### Visualize particle start locations
# We can now see where the particles are seesed by using `pset.show`
#
# **If you are releasing a lot of particles the pset will be very long so you might want to skip printing it.**

# %%
print(pset)
pset.show()
# Out:
# P[7686000](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686001](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686002](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686003](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686004](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686005](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686006](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686007](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686008](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686009](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686010](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686011](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686012](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686013](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686014](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686015](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686016](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686017](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686018](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686019](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686020](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686021](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686022](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686023](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686024](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686025](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686026](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686027](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686028](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686029](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686030](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686031](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686032](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686033](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686034](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686035](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686036](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686037](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686038](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686039](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686040](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686041](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686042](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686043](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686044](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686045](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686046](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686047](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686048](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686049](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686050](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686051](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686052](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686053](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686054](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686055](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686056](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686057](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686058](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686059](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686060](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686061](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686062](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686063](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686064](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686065](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686066](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686067](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686068](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686069](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686070](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686071](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686072](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686073](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686074](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686075](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686076](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686077](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686078](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686079](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686080](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686081](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686082](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686083](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686084](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686085](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686086](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686087](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686088](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686089](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686090](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686091](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686092](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686093](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686094](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686095](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686096](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686097](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686098](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686099](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686100](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686101](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686102](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686103](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686104](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686105](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686106](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686107](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686108](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686109](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686110](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686111](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686112](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686113](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686114](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686115](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686116](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686117](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686118](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686119](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686120](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686121](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686122](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686123](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686124](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686125](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686126](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686127](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686128](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686129](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686130](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686131](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686132](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686133](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686134](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686135](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686136](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686137](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686138](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686139](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686140](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686141](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686142](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686143](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686144](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686145](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686146](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686147](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686148](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686149](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686150](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686151](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686152](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686153](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686154](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686155](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686156](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686157](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686158](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686159](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686160](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686161](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686162](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686163](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686164](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686165](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686166](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686167](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686168](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686169](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686170](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686171](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686172](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686173](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686174](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686175](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686176](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686177](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686178](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686179](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686180](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686181](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686182](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686183](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686184](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686185](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686186](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686187](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686188](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686189](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686190](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686191](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686192](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686193](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686194](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686195](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686196](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686197](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686198](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686199](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686200](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686201](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686202](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686203](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686204](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686205](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686206](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686207](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686208](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686209](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686210](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686211](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686212](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686213](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686214](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686215](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686216](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686217](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686218](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686219](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686220](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686221](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686222](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686223](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686224](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686225](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686226](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686227](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686228](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686229](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686230](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686231](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686232](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686233](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686234](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686235](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686236](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686237](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686238](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686239](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686240](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686241](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686242](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686243](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686244](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686245](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686246](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686247](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686248](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686249](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686250](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686251](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686252](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686253](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686254](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686255](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686256](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686257](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686258](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686259](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686260](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686261](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686262](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686263](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686264](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686265](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686266](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686267](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686268](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686269](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686270](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686271](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686272](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686273](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686274](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686275](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686276](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686277](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686278](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686279](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686280](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686281](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686282](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686283](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686284](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686285](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686286](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686287](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686288](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686289](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686290](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686291](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686292](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686293](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686294](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686295](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686296](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686297](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686298](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686299](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686300](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686301](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686302](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686303](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686304](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686305](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686306](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686307](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686308](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686309](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686310](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686311](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686312](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686313](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686314](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686315](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686316](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686317](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686318](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686319](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686320](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686321](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686322](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686323](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686324](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686325](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686326](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686327](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686328](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686329](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686330](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686331](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686332](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686333](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686334](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686335](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686336](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686337](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686338](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686339](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686340](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686341](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686342](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686343](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686344](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686345](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686346](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686347](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686348](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686349](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686350](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686351](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686352](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686353](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686354](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686355](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686356](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686357](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686358](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686359](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686360](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686361](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686362](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686363](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686364](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686365](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686366](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686367](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# P[7686368](lon=158.318985, lat=6.753577, depth=5.000000, age=0.000000, releaseSite=6.000000, distance=0.000000, time=not_yet_set)
# ...
# P[7695629](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695630](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695631](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695632](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695633](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695634](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695635](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695636](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695637](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695638](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695639](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695640](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695641](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695642](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695643](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695644](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695645](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695646](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695647](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695648](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695649](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695650](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695651](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695652](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695653](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695654](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695655](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695656](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695657](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695658](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695659](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695660](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695661](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695662](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695663](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695664](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695665](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695666](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695667](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695668](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695669](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695670](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695671](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695672](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695673](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695674](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695675](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695676](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695677](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695678](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695679](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695680](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695681](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695682](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695683](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695684](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695685](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695686](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695687](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695688](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695689](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695690](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695691](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695692](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695693](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695694](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695695](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695696](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695697](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695698](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695699](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695700](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695701](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695702](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695703](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695704](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695705](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695706](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695707](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695708](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695709](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695710](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695711](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695712](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695713](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695714](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695715](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695716](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695717](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695718](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695719](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695720](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695721](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695722](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695723](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695724](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695725](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695726](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695727](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695728](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695729](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695730](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695731](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695732](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695733](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695734](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695735](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695736](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695737](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695738](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695739](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695740](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695741](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695742](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695743](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695744](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695745](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695746](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695747](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695748](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)
# P[7695749](lon=190.470001, lat=16.760000, depth=5.000000, age=0.000000, releaseSite=11.000000, distance=0.000000, time=not_yet_set)

# %% [markdown]
# ## Advect particles

# %% [markdown]
# To invoke the custom kernels we wrote earlier we need to combine them into a format Parcels can use. Simply string all the kernels together that you want to use.

# %%
# Combine kernels you are using
kernels = pset.Kernel(AdvectionRK4) + pset.Kernel(Ageing) + pset.Kernel(Distance) + pset.Kernel(DiffusionUniformKh) #pset.Kernel(DiffusionUniformKh) +

# %% [markdown]
# Execute the advection. Depending on how many particles you release and the length of your release this may take some time.
#
# Particles specified in `ParticleSet` are advected using `kernels` at a `model_dt` time step and printed in a netcdf file (`outfile`) at `save_dt` time steps. Particels reaching the limits of the domain are removed through `recovery`.
#
# We are executing `pset.execute` here twice: the first time we are releaseing particles daily (or whatever interval we decided to use). To stop this, we then set `pset.repeatdt = None` followed by a new `pset.execute` that lasts for as long as the PLD. This way, each particle released will run to the end of the pld. That is, the releases will stop PLD days before the end of the run. So you shouldn't have any trajectories with NA's at the end.

# %%
# Time step in model
model_dt = timedelta(hours=1)

# Time step to save to file
save_dt = timedelta(days=1)

# Length of model run
run_days = 365 #365  # how long you want to realease particles for
pld = 180 #180       # how long after the last released particle you want the code to keep running

# Set output file name
#output_file = pset.ParticleFile(name="LAPS_sensitivity_n1_pld180_20m_Kh0_nday545_daily_07012012.nc", outputdt=save_dt)
output_file = pset.ParticleFile(name='LAPS_sensitivity_n750_pld180_5m_Kh10_nday545_daily_07012012_third.nc', outputdt=save_dt)

# don't print depth
pset.set_variable_write_status('depth', False)

# Execute and release daily during this timeframe
pset.execute(kernels,
            runtime=timedelta(days=run_days),
            dt=model_dt, 
            recovery={ErrorCode.ErrorOutOfBounds: DeleteParticle},
            output_file=output_file)

# now stop the repeated release
pset.repeatdt = None

# now continue running for the remaining length of the PLD
pset.execute(kernels,
            runtime=timedelta(days=pld+1),
            dt=model_dt, 
            recovery={ErrorCode.ErrorOutOfBounds: DeleteParticle},
            output_file=output_file)

output_file.export()
# Out:
# Exception ignored in: <function ParticleFileSOA.__del__ at 0x7fe178b22050>
# Traceback (most recent call last):
#   File "/Users/taylorely/opt/miniconda3/envs/py3_parcels/lib/python3.7/site-packages/parcels/particlefile/particlefilesoa.py", line 40, in __del__
#     super(ParticleFileSOA, self).__del__()
#   File "/Users/taylorely/opt/miniconda3/envs/py3_parcels/lib/python3.7/site-packages/parcels/particlefile/baseparticlefile.py", line 235, in __del__
#     self.close()
#   File "/Users/taylorely/opt/miniconda3/envs/py3_parcels/lib/python3.7/site-packages/parcels/particlefile/baseparticlefile.py", line 240, in close
#     self.export()
#   File "/Users/taylorely/opt/miniconda3/envs/py3_parcels/lib/python3.7/site-packages/parcels/particlefile/particlefilesoa.py", line 130, in export
#     tmp_dict = np.load(npyfile, allow_pickle=True).item()
#   File "/Users/taylorely/opt/miniconda3/envs/py3_parcels/lib/python3.7/site-packages/numpy/lib/npyio.py", line 417, in load
#     fid = stack.enter_context(open(os_fspath(file), "rb"))
# FileNotFoundError: [Errno 2] No such file or directory: 'out-TETEEMSY/0/108.npy'
# INFO: Compiled ArrayAgeingParticleAdvectionRK4AgeingDistanceDiffusionUniformKh ==> /var/folders/pj/53kp_v_x76s0cmk3609n2xvr0000gn/T/parcels-501/liba74e93a9ed9cebd517e95a3544b2cb8a_0.so
# INFO: Temporary output files are stored in out-DDZHPXOU.
# INFO: You can use "parcels_convert_npydir_to_netcdf out-DDZHPXOU" to convert these to a NetCDF file during the run.
# 100% (31536000.0 of 31536000.0) |########| Elapsed Time: 2:29:26 Time:  2:29:26
# INFO: Temporary output files are stored in out-DDZHPXOU.
# INFO: You can use "parcels_convert_npydir_to_netcdf out-DDZHPXOU" to convert these to a NetCDF file during the run.
#  98% (15465600.0 of 15638400.0) |####### | Elapsed Time: 0:41:41 ETA:   0:00:01WARNING: ParticleSet is empty on writing as array at time 4.7088e+07
#  99% (15552000.0 of 15638400.0) |####### | Elapsed Time: 0:41:42 ETA:   0:00:00WARNING: ParticleSet is empty on writing as array at time 4.71744e+07
# 100% (15638400.0 of 15638400.0) |########| Elapsed Time: 0:41:42 Time:  0:41:42

# %% [markdown]
# To make sure particles have been advected run `pset.show()` again.

# %% [raw]
# # pset.show()

# %% [markdown]
# ## Visualize the dispersal

# %% [markdown]
# ### Plot trajectories
# Plot the trajectories saved to the netcdf file `outfile` on a map. It's not going to be pretty, but it gives you an idea if the dispersal made sense or not.
#
# **If you have a lot of trajectories this will take a long time. You are better off plotting them using straigt up Python methods, in R, or any other prefered software.**

# %% [markdown]
# plotTrajectoriesFile('LAPS_sensitivity_n10_pld180_5m_Kh10_nday545_daily_07012012_try2.nc', mode='movie2d_notebook')

# %% [markdown]
# ds.distance

# %% [markdown]
# import xarray as xr
# ds = xr.open_dataset('Test_LAPS_sensitivity_stopRelease_180pld_0m.nc')

# %% [markdown]
# ds.sel(releaseSite=slice(0, 100))
# ds.where(ds.releaseSite < 4, drop=True)

# %% [markdown]
# ### Calculate distance traveled
#
# This bit of code calculates the length of each trajectory based on the havesine formula. First I load in the Parcels output ncdf, then loop through the lat and lons to calculate the distances between each timestep. Then we make it into a pandas dataframe and finally save all the distances into a csv file. Distances here are in **Kilometers**
#
# *Note: these distances will be shorter than those listed in the output file, becuase not every model timestep is saved.*

# %% [markdown]
# %%time
# ds = xr.open_dataset('LAPS_sensitivity_n500_pld180_5m_Kh0_nday545_daily_07012012.nc')
#
# df2 = []
# for j in range(len(ds.traj)):
#     #distance = [hs.haversine((ds.lat[j,i], ds.lon[j,i]), (ds.lat[j,i+1], ds.lon[j,i+1])) for i in range(len(ds.obs)-1)]
#     #df2.append(distance)
#
# df3 = pd.DataFrame(np.array(df2).T).sum(axis=0)
# print(df3)
#
# df3.to_csv('LAPS_sensitivity_n500_pld180_5m_Kh0_nday545_daily_07012012.csv')
